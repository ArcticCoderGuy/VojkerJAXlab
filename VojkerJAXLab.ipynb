# %% [markdown]
# <a href="https://colab.research.google.com/github/ArcticCoderGuy/Adaptive-Extraction-Systems/blob/main/VojkerJAXlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.auth
credentials, project_id = google.auth.default()
print(f"Olet kirjautuneena projektiin: {project_id}")
# Out:
# Olet kirjautuneena projektiin:
